# %%
from config import config_data, config_model, config_runtime

# %%
from main import train

# %%
config_data.keys(), config_model.keys()
# Out:
# (dict_keys(['dataset_filepath', 'train_selection_filepath', 'test_selection_filepath', 'max_ba', 'max_size', 'min_num_res', 'l_types', 'r_types']),
#  dict_keys(['em', 'sum', 'spl', 'dm']))

# %%
config_runtime
# Out:
# {'run_name': 'i_v4_1_2025-03-03_22-15',
#  'output_dir': 'save',
#  'reload': True,
#  'device': 'cuda',
#  'num_epochs': 100,
#  'batch_size': 1,
#  'log_step': 1024,
#  'eval_step': 8192,
#  'eval_size': 1024,
#  'learning_rate': 1e-05,
#  'pos_weight_factor': 0.5,
#  'comment': ''}

# %%
train(config_data, config_model, config_runtime, './output')
# Out:
# >>> Configuration
# {'dataset_filepath': 'datasets/contacts_rr5A_64nn_8192.h5', 'train_selection_filepath': 'datasets/subunits_train_set.txt', 'test_selection_filepath': 'datasets/subunits_test_set.txt', 'max_ba': 1, 'max_size': 8192, 'min_num_res': 48, 'l_types': ['GLU', 'LEU', 'ALA', 'ASP', 'SER', 'VAL', 'GLY', 'THR', 'ARG', 'PHE', 'TYR', 'ILE', 'PRO', 'ASN', 'LYS', 'GLN', 'HIS', 'TRP', 'MET', 'CYS'], 'r_types': [['GLU', 'LEU', 'ALA', 'ASP', 'SER', 'VAL', 'GLY', 'THR', 'ARG', 'PHE', 'TYR', 'ILE', 'PRO', 'ASN', 'LYS', 'GLN', 'HIS', 'TRP', 'MET', 'CYS'], ['DA', 'DT', 'DG', 'DC', 'A', 'U', 'G', 'C'], ['MG', 'ZN', 'CL', 'CA', 'NA', 'MN', 'K', 'IOD', 'CD', 'CU', 'FE', 'NI', 'SR', 'BR', 'CO', 'HG'], ['SO4', 'NAG', 'PO4', 'EDO', 'ACT', 'MAN', 'HEM', 'FMT', 'BMA', 'ADP', 'FAD', 'NAD', 'NO3', 'GLC', 'ATP', 'NAP', 'BGC', 'GDP', 'FUC', 'FES', 'FMN', 'GAL', 'GTP', 'PLP', 'MLI', 'ANP', 'H4B', 'AMP', 'NDP', 'SAH', 'OXY'], ['PLM', 'CLR', 'CDL', 'RET']]}
# ...
