# %%
import re

# %%
pdb_filepath = '/home/iscb/wolfson/doririmon/home/order/ubinet/pesto/C_structured/PeSToIntegration/assets/data/structures/pdb/00/pdb100d.ent.gz'
pdb_filepath = '/home/iscb/wolfson/doririmon/home/order/ubinet/pesto/C_structured/PeSToIntegration/assets/data/structures/pdb/zf/pdb4zfj.ent.gz'

# %%
m = re.match(r'*/([a-z0-9]*)\*pdb([0-9]*)\.gz', pdb_filepath)

# %%
m = re.match(r'.*/pdb([a-z0-9]+)\.ent\.gz', pdb_filepath)

# %%
m = re.match(r'.*/pdb/([a-z0-9]+)/pdb([a-z0-9]+)\.ent\.gz', pdb_filepath)

# %%
type(m)
# Out:
# re.Match

# %%
m[1]
# Out:
# 'zf'

# %%
bid, pdbid = m[1], m[2]

# %%
bid, pdbid
# Out:
# ('zf', '4zfj')
